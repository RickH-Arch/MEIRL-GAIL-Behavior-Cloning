# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mat
import os
import datetime
import time
from tqdm import tqdm

mat.rcParams['font.family'] = 'SimHei'
mat.rcParams['font.sans-serif'] = 'SimHei'

#忽略警告
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Reading

# %%
#date
file_list = [
     '0706', '0707', '0708', '0709','0710','0711','0712', '0714', '0715',
    '0718', '0719', '0720', '0722', '0724', '0725', '0726', '0727',
    '0728', '0730', '0731', '0801', '0802', '0803','0804','0805','0806'
,'0807']

df_list = []

for i in tqdm(file_list,):
    df = pd.read_json(os.getcwd()+"\\origin_data\\dacang\\prob2022%s.json" %(i),lines=True)
    
    df_list.append(df)

df_read = pd.concat(df_list)
df_read
# Out:
# 100%|██████████| 27/27 [00:28<00:00,  1.04s/it]
#                                          _id                              m
# 0       {'$oid': '60e32f77f90a6c7ac960a79b'}         [1, 128, 194, 0, 0, 0]  \
# 1       {'$oid': '60e32f77f90a6c7ac960a79c'}    [80, 2, 145, 187, 143, 221]
# 2       {'$oid': '60e32f77f90a6c7ac960a79d'}    [176, 89, 71, 72, 233, 219]
# 3       {'$oid': '60e32f77f90a6c7ac960a79e'}    [160, 65, 71, 44, 196, 200]
# 4       {'$oid': '60e32f77f90a6c7ac960a79f'}     [51, 51, 255, 86, 69, 185]
# ...                                      ...                            ...
# 174556  {'$oid': '62efe057865837f6d4fc457e'}  [88, 102, 186, 101, 140, 144]
# 174557  {'$oid': '62efe057865837f6d4fc457f'}  [88, 102, 186, 101, 140, 144]
# 174558  {'$oid': '62efe057865837f6d4fc4580'}      [1, 0, 94, 127, 255, 250]
# 174559  {'$oid': '62efe057865837f6d4fc4581'}      [1, 0, 94, 127, 255, 250]
# 174560  {'$oid': '62efe057865837f6d4fc4582'}  [88, 102, 186, 101, 140, 144]
#
#           a    r             t
# 0       121  169  1.625501e+09
# 1       121  159  1.625501e+09
# 2       121  160  1.625501e+09
# 3       121  163  1.625501e+09
# 4       121  159  1.625501e+09
# ...     ...  ...           ...
# 174556   66  176  1.659887e+09
# 174557   66  177  1.659887e+09
# 174558   66  161  1.659887e+09
# 174559   66  162  1.659888e+09
# 174560   66  176  1.659888e+09
#
# [4998788 rows x 5 columns]

# %%
# convert time format
df = df_read.copy()

def Convert2Time(t):
    newT = time.localtime(t)
    timeStyle = time.strftime("%Y-%m-%d %H:%M:%S",newT)
    return timeStyle

df['t'] = df['t'].apply(Convert2Time)

#change 2021 -> 2022 (little data bug)
df['t'] = df['t'].apply(lambda t : t.replace('2021','2022'))

#drop _id column
df = df.drop('_id',axis=1)
df
# Out:
#                                     m    a    r                    t
# 0              [1, 128, 194, 0, 0, 0]  121  169  2022-07-05 23:57:16
# 1         [80, 2, 145, 187, 143, 221]  121  159  2022-07-05 23:57:16
# 2         [176, 89, 71, 72, 233, 219]  121  160  2022-07-05 23:57:16
# 3         [160, 65, 71, 44, 196, 200]  121  163  2022-07-05 23:57:16
# 4          [51, 51, 255, 86, 69, 185]  121  159  2022-07-05 23:57:20
# ...                               ...  ...  ...                  ...
# 174556  [88, 102, 186, 101, 140, 144]   66  176  2022-08-07 23:48:38
# 174557  [88, 102, 186, 101, 140, 144]   66  177  2022-08-07 23:51:14
# 174558      [1, 0, 94, 127, 255, 250]   66  161  2022-08-07 23:51:14
# 174559      [1, 0, 94, 127, 255, 250]   66  162  2022-08-07 23:54:42
# 174560  [88, 102, 186, 101, 140, 144]   66  176  2022-08-07 23:54:42
#
# [4998788 rows x 4 columns]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### wash macs with unusual length

# %%
df = df[df.m.apply(lambda x : True if len(x) == 6 else False)]
df
# Out:
#                                     m    a    r                    t
# 0              [1, 128, 194, 0, 0, 0]  121  169  2022-07-05 23:57:16
# 1         [80, 2, 145, 187, 143, 221]  121  159  2022-07-05 23:57:16
# 2         [176, 89, 71, 72, 233, 219]  121  160  2022-07-05 23:57:16
# 3         [160, 65, 71, 44, 196, 200]  121  163  2022-07-05 23:57:16
# 4          [51, 51, 255, 86, 69, 185]  121  159  2022-07-05 23:57:20
# ...                               ...  ...  ...                  ...
# 174556  [88, 102, 186, 101, 140, 144]   66  176  2022-08-07 23:48:38
# 174557  [88, 102, 186, 101, 140, 144]   66  177  2022-08-07 23:51:14
# 174558      [1, 0, 94, 127, 255, 250]   66  161  2022-08-07 23:51:14
# 174559      [1, 0, 94, 127, 255, 250]   66  162  2022-08-07 23:54:42
# 174560  [88, 102, 186, 101, 140, 144]   66  176  2022-08-07 23:54:42
#
# [4982938 rows x 4 columns]

# %% [markdown]
# ### wash macs that contains 0

# %%
df = df[df.m.apply(lambda x : False if 0 in x else True)]
df
# Out:
#                                     m    a    r                    t
# 1         [80, 2, 145, 187, 143, 221]  121  159  2022-07-05 23:57:16
# 2         [176, 89, 71, 72, 233, 219]  121  160  2022-07-05 23:57:16
# 3         [160, 65, 71, 44, 196, 200]  121  163  2022-07-05 23:57:16
# 4          [51, 51, 255, 86, 69, 185]  121  159  2022-07-05 23:57:20
# 5         [80, 2, 145, 187, 143, 221]  121  164  2022-07-05 23:57:20
# ...                               ...  ...  ...                  ...
# 174552  [88, 102, 186, 101, 140, 144]   66  177  2022-08-07 23:44:30
# 174553  [88, 102, 186, 101, 140, 144]   66  177  2022-08-07 23:46:54
# 174556  [88, 102, 186, 101, 140, 144]   66  176  2022-08-07 23:48:38
# 174557  [88, 102, 186, 101, 140, 144]   66  177  2022-08-07 23:51:14
# 174560  [88, 102, 186, 101, 140, 144]   66  176  2022-08-07 23:54:42
#
# [3633753 rows x 4 columns]

# %% [markdown]
# ### wash fake macs

# %% [markdown]
# #### 清除多播mac地址和广播mac地址
#
# **单播地址（unicast address**）表示单一设备、节点；
#
# **多播地址或者组播地址（multicast address 、 group address）** 表示一组设备、节点；
#
# **广播地址（broadcast address）** 是组播的特例，表示所有地址，全用F表示：FF:FF:FF:FF:FF:FF。
#
#
# 如MAC地址：54-BF-64-2B-09-50，第1个字节是54，第2个字节是BF …，而十六进制54写成二进制为：01010100，红色位标识代表的组播地址与单播地址区分位，单播地址红色位一定为0，即MAC地址一的第一个字节一定是2的倍数.

# %%
df = df[df.m.apply(lambda x :True if x[0]%2 == 0 else False)]
df
# Out:
#                                     m    a    r                    t
# 1         [80, 2, 145, 187, 143, 221]  121  159  2022-07-05 23:57:16
# 2         [176, 89, 71, 72, 233, 219]  121  160  2022-07-05 23:57:16
# 3         [160, 65, 71, 44, 196, 200]  121  163  2022-07-05 23:57:16
# 5         [80, 2, 145, 187, 143, 221]  121  164  2022-07-05 23:57:20
# 7           [96, 238, 92, 49, 127, 3]  121  183  2022-07-05 23:57:33
# ...                               ...  ...  ...                  ...
# 174552  [88, 102, 186, 101, 140, 144]   66  177  2022-08-07 23:44:30
# 174553  [88, 102, 186, 101, 140, 144]   66  177  2022-08-07 23:46:54
# 174556  [88, 102, 186, 101, 140, 144]   66  176  2022-08-07 23:48:38
# 174557  [88, 102, 186, 101, 140, 144]   66  177  2022-08-07 23:51:14
# 174560  [88, 102, 186, 101, 140, 144]   66  176  2022-08-07 23:54:42
#
# [3319842 rows x 4 columns]

# %% [markdown]
# 根据IEEE 802 MAC地址的定义，若MAC地址第一个字节的从低位开始的第二个bit为1，则表示该MAC地址类型为本地管理类型，本地管理类型MAC地址不保证是全局唯一的。随机MAC一般选用本地管理类型的MAC地址。

# %%
def IsFakeMac(x):
    x = format(x[0],'04b')
    n = len(x) - 2
    if x[n] == '1':
        return True
    else:
        return False
    
df = df[~df.m.apply(IsFakeMac)]
df
# Out:
#                                     m    a    r                    t
# 1         [80, 2, 145, 187, 143, 221]  121  159  2022-07-05 23:57:16
# 2         [176, 89, 71, 72, 233, 219]  121  160  2022-07-05 23:57:16
# 3         [160, 65, 71, 44, 196, 200]  121  163  2022-07-05 23:57:16
# 5         [80, 2, 145, 187, 143, 221]  121  164  2022-07-05 23:57:20
# 7           [96, 238, 92, 49, 127, 3]  121  183  2022-07-05 23:57:33
# ...                               ...  ...  ...                  ...
# 174552  [88, 102, 186, 101, 140, 144]   66  177  2022-08-07 23:44:30
# 174553  [88, 102, 186, 101, 140, 144]   66  177  2022-08-07 23:46:54
# 174556  [88, 102, 186, 101, 140, 144]   66  176  2022-08-07 23:48:38
# 174557  [88, 102, 186, 101, 140, 144]   66  177  2022-08-07 23:51:14
# 174560  [88, 102, 186, 101, 140, 144]   66  176  2022-08-07 23:54:42
#
# [2036283 rows x 4 columns]

# %% [markdown]
# ### Convert Mac to String

# %%
def convertMac2Str(x):
    list_s = map(str,x)
    s = ','.join(list_s)
    return s

df['m'] = df['m'].apply(convertMac2Str)
df.head()
# Out:
#                       m    a    r                    t
# 1  80,2,145,187,143,221  121  159  2022-07-05 23:57:16
# 2  176,89,71,72,233,219  121  160  2022-07-05 23:57:16
# 3  160,65,71,44,196,200  121  163  2022-07-05 23:57:16
# 5  80,2,145,187,143,221  121  164  2022-07-05 23:57:20
# 7    96,238,92,49,127,3  121  183  2022-07-05 23:57:33

# %%
df = df.reindex(columns = ['a','r','t','m'])
df.head()
# Out:
#      a    r                    t                     m
# 1  121  159  2022-07-05 23:57:16  80,2,145,187,143,221
# 2  121  160  2022-07-05 23:57:16  176,89,71,72,233,219
# 3  121  163  2022-07-05 23:57:16  160,65,71,44,196,200
# 5  121  164  2022-07-05 23:57:20  80,2,145,187,143,221
# 7  121  183  2022-07-05 23:57:33    96,238,92,49,127,3

# %% [markdown]
# ### wash macs that only appeared once

# %%
df = df[df.duplicated("m",keep = False)]
df
# Out:
#           a    r                    t                       m
# 1       121  159  2022-07-05 23:57:16    80,2,145,187,143,221
# 2       121  160  2022-07-05 23:57:16    176,89,71,72,233,219
# 3       121  163  2022-07-05 23:57:16    160,65,71,44,196,200
# 5       121  164  2022-07-05 23:57:20    80,2,145,187,143,221
# 7       121  183  2022-07-05 23:57:33      96,238,92,49,127,3
# ...     ...  ...                  ...                     ...
# 174552   66  177  2022-08-07 23:44:30  88,102,186,101,140,144
# 174553   66  177  2022-08-07 23:46:54  88,102,186,101,140,144
# 174556   66  176  2022-08-07 23:48:38  88,102,186,101,140,144
# 174557   66  177  2022-08-07 23:51:14  88,102,186,101,140,144
# 174560   66  176  2022-08-07 23:54:42  88,102,186,101,140,144
#
# [1967498 rows x 4 columns]

# %% [markdown]
# ### wash macs that only appeared in one place

# %%
list_count = df.groupby(['m']).a.value_counts()
dd = list_count.to_frame().rename(columns={'a':'A'}).reset_index()
mac_Once = dd[~dd.duplicated('m', keep=False)].m.reset_index().drop('index',axis=1)
mac_Once
# Out:
#                            m
# 0     100,145,159,224,55,191
# 1      100,145,159,48,148,53
# 2     100,145,162,146,189,25
# 3     100,145,163,172,115,82
# 4      100,145,163,48,148,53
# ...                      ...
# 8196   96,98,173,154,151,204
# 8197      96,98,173,86,34,94
# 8198      96,98,175,32,50,51
# 8199      96,98,175,86,34,94
# 8200     96,98,177,1,128,194
#
# [8201 rows x 1 columns]

# %%
#删除mac_Once对应的mac地址
df = df.loc[~df.m.isin(mac_Once.m)]
df
# Out:
#          a    r                    t                        m
# 12605   22  171  2022-07-05 23:49:36      48,74,38,155,214,98
# 12606   22  163  2022-07-05 23:49:36    252,107,240,89,142,53
# 12607   22  170  2022-07-05 23:49:36  164,125,159,153,152,106
# 12615   22  166  2022-07-05 23:49:47    252,107,240,89,142,53
# 12616   22  170  2022-07-05 23:49:47  164,125,159,153,152,106
# ...     ..  ...                  ...                      ...
# 174552  66  177  2022-08-07 23:44:30   88,102,186,101,140,144
# 174553  66  177  2022-08-07 23:46:54   88,102,186,101,140,144
# 174556  66  176  2022-08-07 23:48:38   88,102,186,101,140,144
# 174557  66  177  2022-08-07 23:51:14   88,102,186,101,140,144
# 174560  66  176  2022-08-07 23:54:42   88,102,186,101,140,144
#
# [1916101 rows x 4 columns]

# %% [markdown]
# ### Convert RSSI

# %%
df.r = df.loc[:,'r'].apply(lambda x : format(x,'04b'))

def bin2dec(b):
    number = 0
    counter = 0
    for i in b[::-1]: 
        number += int(i)*(2**counter)
        counter += 1

    return number

def Rssi2dec(r):
    n = bin2dec(r[1:8])
    if r[0] == '0':
        return n
    else:
        return -n
    
df.r = df.r.apply(Rssi2dec)
df
# Out:
# C:\Users\ricks\AppData\Local\Temp\ipykernel_3700\1247547355.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.r = df.r.apply(Rssi2dec)
#          a   r                    t                        m
# 12605   22 -43  2022-07-05 23:49:36      48,74,38,155,214,98
# 12606   22 -35  2022-07-05 23:49:36    252,107,240,89,142,53
# 12607   22 -42  2022-07-05 23:49:36  164,125,159,153,152,106
# 12615   22 -38  2022-07-05 23:49:47    252,107,240,89,142,53
# 12616   22 -42  2022-07-05 23:49:47  164,125,159,153,152,106
# ...     ..  ..                  ...                      ...
# 174552  66 -49  2022-08-07 23:44:30   88,102,186,101,140,144
# 174553  66 -49  2022-08-07 23:46:54   88,102,186,101,140,144
# 174556  66 -48  2022-08-07 23:48:38   88,102,186,101,140,144
# 174557  66 -49  2022-08-07 23:51:14   88,102,186,101,140,144
# 174560  66 -48  2022-08-07 23:54:42   88,102,186,101,140,144
#
# [1916101 rows x 4 columns]

# %%
df.to_csv(os.getcwd()+'\\cleaned_data\\dacang\\dacang_cleaned_data(indoor including)1104.csv',index = False)

# %% [markdown]
# # 24h Data clean

# %%
#label each mac with date
pbar = tqdm(total=len(df))
df['oriMac'] = df['m']
df.t = pd.to_datetime(df.t)
df['calender'] = df.t.apply(lambda x : str(x.month)+'.'+str(x.day))
for index,row in df.iterrows():
    df.loc[index,'m'] = str(row['calender'])+'-'+row.m
    pbar.update(1)
pbar.close()
df
# Out:
#   0%|          | 87/1916101 [00:37<226:52:43,  2.35it/s]
#   4%|▍         | 73579/1916101 [13:07:48<33:47:22, 15.15it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 7
#       5 df['calender'] = df.t.apply(lambda x : str(x.month)+'.'+str(x.day))
#       6 for index,row in df.iterrows():
# ----> 7     df.loc[index,'m'] = str(row['calender'])+'-'+row.m
#       8     pbar.update(1)
#       9 pbar.close()
#
# File c:\ProgramData\anaconda3\envs\pytorch\lib\site-packages\pandas\core\indexing.py:849, in _LocationIndexer.__setitem__(self, key, value)
#     846 self._has_valid_setitem_indexer(key)
#     848 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 849 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File c:\ProgramData\anaconda3\envs\pytorch\lib\site-packages\pandas\core\indexing.py:1828, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1825 # align and set the values
#    1826 if take_split_path:
#    1827     # We have to operate column-wise
# -> 1828     self._setitem_with_indexer_split_path(indexer, value, name)
#    1829 else:
#    1830     self._setitem_single_block(indexer, value, name)
#
# File c:\ProgramData\anaconda3\envs\pytorch\lib\site-packages\pandas\core\indexing.py:1921, in _iLocIndexer._setitem_with_indexer_split_path(self, indexer, value, name)
#    1918 else:
#    1919     # scalar value
#    1920     for loc in ilocs:
# -> 1921         self._setitem_single_column(loc, value, pi)
#
# File c:\ProgramData\anaconda3\envs\pytorch\lib\site-packages\pandas\core\indexing.py:2027, in _iLocIndexer._setitem_single_column(self, loc, value, plane_indexer)
#    2023         self.obj.isetitem(loc, value)
#    2024 else:
#    2025     # set value into the column (first attempting to operate inplace, then
#    2026     #  falling back to casting if necessary)
# -> 2027     self.obj._mgr.column_setitem(loc, plane_indexer, value)
#    2029 self.obj._clear_item_cache()
#
# File c:\ProgramData\anaconda3\envs\pytorch\lib\site-packages\pandas\core\internals\managers.py:1385, in BlockManager.column_setitem(self, loc, idx, value, inplace_only)
#    1383 else:
#    1384     new_mgr = col_mgr.setitem((idx,), value)
# -> 1385     self.iset(loc, new_mgr._block.values, inplace=True)
#
# File c:\ProgramData\anaconda3\envs\pytorch\lib\site-packages\pandas\core\internals\managers.py:1174, in BlockManager.iset(self, loc, value, inplace)
#    1172 blk = self.blocks[blkno]
#    1173 if len(blk._mgr_locs) == 1:  # TODO: fastest way to check this?
# -> 1174     return self._iset_single(
#    1175         loc,
#    1176         value,
#    1177         inplace=inplace,
#    1178         blkno=blkno,
#    1179         blk=blk,
#    1180     )
#    1182 # error: Incompatible types in assignment (expression has type
#    1183 # "List[Union[int, slice, ndarray]]", variable has type "Union[int,
#    1184 # slice, ndarray]")
#    1185 loc = [loc]  # type: ignore[assignment]
#
# File c:\ProgramData\anaconda3\envs\pytorch\lib\site-packages\pandas\core\internals\managers.py:1346, in BlockManager._iset_single(self, loc, value, inplace, blkno, blk)
#    1344         copy = True
#    1345     iloc = self.blklocs[loc]
# -> 1346     blk.set_inplace(slice(iloc, iloc + 1), value, copy=copy)
#    1347     return
#    1349 nb = new_block_2d(value, placement=blk._mgr_locs)
#
# KeyboardInterrupt:

# %%
#删除打上标签后只出现过一次的mac
df = df[df.duplicated('m',keep=False)]
df
